# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("car_data[1].csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# ...

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.isnull()
# Out:
#      Car_Name   Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       False  False          False          False       False      False
# 1       False  False          False          False       False      False
# 2       False  False          False          False       False      False
# 3       False  False          False          False       False      False
# 4       False  False          False          False       False      False
# ..        ...    ...            ...            ...         ...        ...
# 296     False  False          False          False       False      False
# 297     False  False          False          False       False      False
# 298     False  False          False          False       False      False
# 299     False  False          False          False       False      False
# 300     False  False          False          False       False      False
#
#      Selling_type  Transmission  Owner
# 0           False         False  False
# ...

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# Length: 301, dtype: bool

# %%
sns.countplot(data=data,x="Selling_type")
plt.show()

# %%
ax=sns.countplot(data=data,x="Selling_type")
for bars in ax.containers:ax.bar_label(bars)

# %%
sns.barplot(data=data.head(15),x="Car_Name",y="Selling_Price")
plt.show()

# %%
car_group=data.groupby(["Car_Name"],as_index=False)["Car_Name"].sum().sort_values(by="Car_Name",ascending=False)
car_group
# Out:
#                                              Car_Name
# 97                                    xcentxcentxcent
# 96                       wagon rwagon rwagon rwagon r
# 95                                      vitara brezza
# 94  vernavernavernavernavernavernavernavernavernav...
# 93                                 sx4sx4sx4sx4sx4sx4
# ..                                                ...
# 4                                   Bajaj Avenger 150
# 3                                       Bajaj  ct 100
# 2                                           Activa 4g
# 1                                  Activa 3gActiva 3g
# 0                                                 800
#
# [98 rows x 1 columns]

# %%
plt.figure(figsize=(5,7))
sns.countplot(data=car_group.head(10) ,x="Car_Name")
plt.xticks(rotation=90)
plt.show()

# %%
distance=data.groupby(["Car_Name"],as_index=False)["Driven_kms"].sum().sort_values(by="Driven_kms",ascending=False)
distance
# Out:
#               Car_Name  Driven_kms
# 69                city     1021720
# 71       corolla altis      868702
# 81            fortuner      689731
# 94               verna      598462
# 86              innova      528418
# ..                 ...         ...
# 95       vitara brezza        2071
# 50   Suzuki Access 125        1900
# 56  UM Renegade Mojave        1400
# 2            Activa 4g        1300
# 11   Bajaj Dominar 400        1200
#
# [98 rows x 2 columns]

# %%
sns.barplot(data=distance.head(25),x="Car_Name",y="Driven_kms")
plt.show()

# %%
plt.figure(figsize=(30,7))
ax=sns.barplot(data=distance.head(20),x="Car_Name",y="Driven_kms")
for bars in ax.containers:ax.bar_label(bars)

# %%
data.tail
# Out:
# <bound method NDFrame.tail of     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.model_selection import train_test_split

# %%
x = data[['Year', 'Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type', 'Transmission', 'Owner']]
y = data['Selling_Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Year  Present_Price  Driven_kms Fuel_Type Selling_type Transmission  \
# 184  2008          0.750       26000    Petrol   Individual       Manual
# 132  2017          0.950        3500    Petrol   Individual       Manual
# 194  2008          0.787       50000    Petrol   Individual       Manual
# 75   2015          6.800       36000    Petrol       Dealer       Manual
# 111  2016          1.500        8700    Petrol   Individual       Manual
# ..    ...            ...         ...       ...          ...          ...
# 188  2013          0.570       18000    Petrol   Individual       Manual
# 71   2011         12.480       45000    Diesel       Dealer       Manual
# 106  2014          3.450       16500    Petrol   Individual       Manual
# 270  2011         10.000       69341    Petrol       Dealer       Manual
# 102  2017          1.780        4000    Petrol   Individual       Manual
#
#      Owner
# 184      1
# 132      0
# 194      0
# 75       0
# 111      0
# ..     ...
# ...

# %%
y_train
# Out:
# 184    0.25
# 132    0.75
# 194    0.20
# 75     3.95
# 111    1.15
#        ...
# 188    0.25
# 71     4.50
# 106    1.35
# 270    4.10
# 102    1.65
# Name: Selling_Price, Length: 240, dtype: float64

# %%
x_test
# Out:
#      Year  Present_Price  Driven_kms Fuel_Type Selling_type Transmission  \
# 177  2016           0.57       24000    Petrol   Individual    Automatic
# 289  2016          13.60       10980    Petrol       Dealer       Manual
# 228  2012           9.40       60000    Diesel       Dealer       Manual
# 198  2011           0.57       35000    Petrol   Individual       Manual
# 60   2013          18.61       40001    Petrol       Dealer       Manual
# ..    ...            ...         ...       ...          ...          ...
# 234  2015           5.70        4492    Petrol       Dealer       Manual
# 296  2016          11.60       33988    Diesel       Dealer       Manual
# 281  2006           7.60       50456    Petrol       Dealer       Manual
# 285  2016           8.50       15059    Petrol       Dealer    Automatic
# 182  2013           0.58       30000    Petrol   Individual       Manual
#
#      Owner
# 177      0
# 289      0
# 228      0
# 198      1
# 60       0
# ..     ...
# ...

# %%
y_test
# Out:
# 177     0.35
# 289    10.11
# 228     4.95
# 198     0.15
# 60      6.95
#        ...
# 234     5.50
# 296     9.50
# 281     2.10
# 285     7.40
# 182     0.30
# Name: Selling_Price, Length: 61, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_167/3557823984.py in ?()
# ----> 1 lr.fit(x_train,y_train)
#
# ~/.local/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py in ?(self, X, y, sample_weight)
#    1192             _dtype = np.float64
#    1193         else:
#    1194             _dtype = [np.float64, np.float32]
#    1195
# -> 1196         X, y = self._validate_data(
#    1197             X,
#    1198             y,
#    1199             accept_sparse="csr",
#
# ~/.local/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     580                 if "estimator" not in check_y_params:
#     581                     check_y_params = {**default_check_params, **check_y_params}
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
sns.boxplot(data=data,x="Present_Price")
plt.show()

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
sns.boxplot(data=data,x="Selling_Price")
plt.show()

# %%
data['Car_Age'] = 2024 - data['Year']
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner  Car_Age
# 0       Dealer       Manual      0       10
# 1       Dealer       Manual      0       11
# 2       Dealer       Manual      0        7
# 3       Dealer       Manual      0       13
# 4       Dealer       Manual      0       10

# %%
sns.countplot(data=data,x="Fuel_Type")
plt.show()

# %%
ax=sns.countplot(data=data,x="Fuel_Type")
for bars in ax.containers:ax.bar_label(bars)

# %%
sns.countplot(data=data,x="Transmission")
plt.show()

# %%
ax=sns.countplot(data=data,x="Transmission")
for bars in ax.containers:ax.bar_label(bars)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
w= data.drop(['Car_Name','Selling_Price'],axis=1)
z= data['Selling_Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(w,z,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Year  Present_Price  Driven_kms  Fuel_Type  Owner  Car_Age  \
# 184  2008          0.750       26000          0      1       16
# 132  2017          0.950        3500          0      0        7
# 194  2008          0.787       50000          0      0       16
# 75   2015          6.800       36000          0      0        9
# 111  2016          1.500        8700          0      0        8
# ..    ...            ...         ...        ...    ...      ...
# 188  2013          0.570       18000          0      0       11
# 71   2011         12.480       45000          1      0       13
# 106  2014          3.450       16500          0      1       10
# 270  2011         10.000       69341          0      0       13
# 102  2017          1.780        4000          0      0        7
#
#      Selling_type_Dealer  Selling_type_Individual  Transmission_Automatic  \
# 184                    0                        1                       0
# ...

# %%
ordinal_map = {'CNG':2,'Diesel':1,'Petrol':0}
data['Fuel_Type'] = data['Fuel_Type'].map(ordinal_map)
data['Fuel_Type'] = data['Fuel_Type'].astype('int64')

# %%
data = pd.get_dummies(data, columns = ['Selling_type','Transmission'])

# %%
data.dtypes
# Out:
# Car_Name                    object
# Year                         int64
# Selling_Price              float64
# Present_Price              float64
# Driven_kms                   int64
# Fuel_Type                    int64
# Owner                        int64
# Car_Age                      int64
# Selling_type_Dealer           bool
# Selling_type_Individual       bool
# Transmission_Automatic        bool
# Transmission_Manual           bool
# dtype: object

# %%
bool_columns = ['Selling_type_Dealer','Selling_type_Individual', 'Transmission_Automatic', 'Transmission_Manual']

data[bool_columns] = data[bool_columns].astype('int64')

# %%
lr.predict(x_test)
# Out:
# array([ 2.96562958,  8.30085782,  6.05782751, -1.46736816,  9.25705687,
#         7.03171029,  1.35032876,  0.82691573,  1.36987479,  7.10758777,
#         8.74146173,  0.58642748,  8.50459253,  3.42661966,  6.50292735,
#         3.08732011,  0.46492161, 10.89305942,  1.76225878,  2.36483065,
#         0.37623881,  7.73151022,  6.20981391,  2.65038024,  0.78195056,
#         3.72251099,  5.3340761 ,  2.84078903,  2.15815992,  1.77018609,
#         0.37934652,  8.79022344, -0.69755203,  2.30364091,  8.21352459,
#         4.54034656,  7.35264949,  7.68532992,  2.91820641,  8.08316508,
#         4.00325157,  4.35384555,  4.36428366,  0.60942277,  6.94443091,
#         0.47315352,  7.41534765, 11.442946  ,  3.14938081,  4.95296902,
#         6.86419835,  2.19604944, 20.53785454, 16.78959932,  7.13843807,
#         9.82975063,  4.49877206,  8.61930717,  1.81754614,  7.67258754,
#         0.21141592])

# %%
lr.predict(x_train)
# Out:
# array([-2.42696421e+00,  1.97061122e+00, -1.62101205e+00,  4.80961243e+00,
#         1.82125458e+00,  2.02080706e+01,  1.82229829e+01,  5.48471346e+00,
#        -6.70098966e-01,  4.60047886e+00,  5.45152488e+00,  5.69700730e+00,
#         4.99145458e+00,  2.74641677e+00,  1.63284799e+00,  1.91398855e+00,
#         1.00885009e+01,  7.95055902e-01,  7.87882116e+00,  4.53198219e+00,
#         3.37842791e+00,  4.55131927e+00,  1.45017192e+01,  2.29509381e+00,
#         3.08147746e+00,  9.27130127e-01,  3.48512041e+00,  1.14579807e+00,
#         1.68657184e+01,  1.39974988e+00,  1.89534025e-01,  9.16919712e+00,
#         8.21352459e+00,  4.31344826e+00, -2.57204227e+00,  4.19550129e+00,
#         6.12584827e+00,  4.38792599e+00, -3.20076619e+00,  7.85805268e+00,
#        -7.79772533e-01,  6.71106331e+00,  3.85651517e+00,  1.01984316e+01,
#         2.46500908e+00,  1.15107144e+01,  2.41859291e+00, -3.07307307e-01,
# ...
